# %%
# !pip install prophet
# !pip install yfinance
# Out:
# Requirement already satisfied: prophet in c:\users\sean\anaconda3\envs\dev\lib\site-packages (1.1.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from prophet) (1.2.0)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from prophet) (1.24.3)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from prophet) (3.7.2)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from prophet) (2.0.3)
# Requirement already satisfied: holidays>=0.25 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from prophet) (0.39)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from prophet) (4.65.0)
# Requirement already satisfied: importlib-resources in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from prophet) (6.1.1)
# Requirement already satisfied: stanio~=0.3.0 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from cmdstanpy>=1.0.4->prophet) (0.3.0)
# Requirement already satisfied: python-dateutil in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from matplotlib>=2.0.0->prophet) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from pandas>=1.0.4->prophet) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from pandas>=1.0.4->prophet) (2023.3)
# Requirement already satisfied: colorama in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)
# Requirement already satisfied: yfinance in c:\users\sean\anaconda3\envs\dev\lib\site-packages (0.2.33)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sean\anaconda3\envs\dev\lib\site-packages (from requests>=2.31->yfinance) (2023.7.22)

# %%
# Run 1st

import pandas as pd
import requests
import json
import datetime as dt
from prophet import Prophet
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Run 2nd
ticker_list = ['CCL', 'RCL', 'NCLH', 'CUK', 'LIND']
# ticker_list = ['BKNG', 'MAR', 'HLT', 'LVS', 'RCL', 'DAL', 'CCL', 'EXPE', 'LUV', 'MGM', 'HST', 'UAL', 'H', 'WYNN', 'AAL', 'MTN', 'NCLH', 'RHP', 'CHH', 'ALK', 'TRIP', 'TNL', 'SHO', 'SKYW', 'PEB', 'JBLU', 'SAVE', 'ALGT', 'BVH', 'ATSG', 'CAR']
# Example list of tickers

# running_shorts_df = pd.read_csv("resources/running_shorts.csv", skiprows=1, header=None, names=['Month', 'Running Shorts'])
# tennis_skirt_df = pd.read_csv('resources/tennis_skirt.csv', skiprows=1, header=None, names=['Month', 'Tennis Skirts'])
# lulu_lemon_df = pd.read_csv('resources/lululemon.csv', skiprows=1, header=None, names=['Month', 'lululemon Sales'])
# carnival_cruises_df = pd.read_csv('resources/carnival_cruises.csv', skiprows=1, header=None, names=['Month', 'Carnival Cruises'])

# Lodging
# airbnb_df = pd.read_csv("resources/airbnb.csv", skiprows=1, header=None, names=['Month', 'Airbnb'])
# bluegreen_vacations_df = pd.read_csv("resources/bluegreen_vacations.csv", skiprows=1, header=None, names=['Month', 'Bluegreen Vacations'])
# booking_dot_com_df = pd.read_csv("resources/booking_dot_com.csv", skiprows=1, header=None, names=['Month', 'Booking.com'])
# choice_hotels_international_df  = pd.read_csv("resources/choice_hotels_international.csv", skiprows=1, header=None, names=['Month', 'Choice Hotels International'])
# hilton_df  = pd.read_csv("resources/hilton.csv", skiprows=1, header=None, names=['Month', 'Hilton'])
# hotels_df  = pd.read_csv("resources/hotels.csv", skiprows=1, header=None, names=['Month', 'Hotels'])
# hyatt_df  = pd.read_csv("resources/hyatt.csv", skiprows=1, header=None, names=['Month', ' Hyatt'])
# marriott_df  = pd.read_csv("resources/marriott.csv", skiprows=1, header=None, names=['Month', 'Marriott'])
# motels_df  = pd.read_csv("resources/motels.csv", skiprows=1, header=None, names=['Month', 'Motels'])
# wyndham_df  = pd.read_csv("resources/wyndham.csv", skiprows=1, header=None, names=['Month', 'Wyndham'])
# wynn_df  = pd.read_csv("resources/wynn.csv", skiprows=1, header=None, names=['Month', 'Wynn'])

# Air
# air_transport_services_group_df  = pd.read_csv("resources/air_transport_services_group.csv ", skiprows=1, header=None, names=['Month', 'Air Transport Services Group'])
# alaska_airlines_df = pd.read_csv("resources/alaska_airlines.csv", skiprows=1, header=None, names=['Month', 'Alaska Airlines'])
# allegiant_air_df = pd.read_csv("resources/allegiant_air.csv", skiprows=1, header=None, names=['Month', 'Allegiant Air'])
# american_airlines_df = pd.read_csv("resources/american_airlines.csv", skiprows=1, header=None, names=['Month', 'American Airlines'])
# delta_airlines_df  = pd.read_csv("resources/delta_airlines.csv", skiprows=1, header=None, names=['Month', 'Delta Airlines'])
# delta_air_lines_df  = pd.read_csv("resources/delta_air_lines.csv", skiprows=1, header=None, names=['Month', 'Delta Air Lines'])
# flights_df  = pd.read_csv("resources/flights.csv", skiprows=1, header=None, names=['Month', 'Flights'])
# frontier_airlines_df  = pd.read_csv("resources/frontier_airlines.csv", skiprows=1, header=None, names=['Month', 'Frontier Airlines'])
# jetblue_df  = pd.read_csv("resources/jetblue.csv", skiprows=1, header=None, names=['Month', 'Jetblue'])
# skywest_airlines_df  = pd.read_csv("resources/skywest_airlines.csv", skiprows=1, header=None, names=['Month', 'Skywest Airlines'])
# southwest_airlines = pd.read_csv("resources/southwest_airlines.csv", skiprows=1, header=None, names=['Month', 'Southwest Airlines'])
# spirit_airlines_df  = pd.read_csv("resources/spirit_airlines.csv", skiprows=1, header=None, names=['Month', 'Spirit Airlines'])
# united_airlines_df  = pd.read_csv("resources/united_airlines.csv", skiprows=1, header=None, names=['Month', 'United Airlines'])

# Sea - original dfs
carnival_cruises_df = pd.read_csv("resources/carnival_cruises.csv", skiprows=1, header=None, names=['Month', 'Carnival Cruise Lines'])
carnival_cruise_lines_df = pd.read_csv("resources/carnival_cruise_lines.csv", skiprows=1, header=None, names=['Month', 'Carnival Cruises'])
cruises_df = pd.read_csv("resources/cruises.csv", skiprows=1, header=None, names=['Month', 'Cruises'])
norwegian_cruises_df = pd.read_csv("resources/norwegian_cruises.csv", skiprows=1, header=None, names=['Month', 'Norwegian Cruises'])
royal_caribbean_df = pd.read_csv("resources/royal_caribbean.csv", skiprows=1, header=None, names=['Month', 'Royal Caribbean'])
# Sea - additional
best_cruise_line_df = pd.read_csv("resources/best_cruise_line.csv", skiprows=1, header=None, names=['Month', 'Best Cruise Line'])
most_fun_cruise_df = pd.read_csv("resources/most_fun_cruise.csv", skiprows=1, header=None, names=['Month', 'Most Fun Cruise'])

# # Land
# car_rental_df  = pd.read_csv("resources/car_rental.csv", skiprows=1, header=None, names=['Month', 'Car Rental'])
# avis_df = pd.read_csv("resources/avis.csv", skiprows=1, header=None, names=['Month', 'Avis'])
# enterprise_df = pd.read_csv("resources/enterprise.csv", skiprows=1, header=None, names=['Month', 'Enterprise'])
# hertz_df = pd.read_csv("resources/hertz.csv", skiprows=1, header=None, names=['Month', 'Hertz'])
# budget_df = pd.read_csv("resources/budget.csv", skiprows=1, header=None, names=['Month', 'Budget'])
# alamo_df = pd.read_csv("resources/alamo.csv", skiprows=1, header=None, names=['Month', 'Alamo'])

# # Locations
# asia_vacation_df = pd.read_csv("resources/asia_vacation.csv", skiprows=1, header=None, names=['Month', 'Asia Vacation'])
# best_cities_for_foodies_df  = pd.read_csv("resources/best_cities_for_foodies.csv", skiprows=1, header=None, names=['Month', 'Best Cities for Foodies'])
# best_cities_to_visit_df = pd.read_csv("resources/best_cities_to_visit.csv", skiprows=1, header=None, names=['Month', 'Best Cities to Visit'])
# best_tourist_spots_df = pd.read_csv("resources/best_tourist_spots.csv", skiprows=1, header=None, names=['Month', 'Best Tourist Spots'])
# big_city_vacations_df = pd.read_csv("resources/big_city_vacations.csv", skiprows=1, header=None, names=['Month', 'Big City Vacations'])
# california_vacation_df = pd.read_csv("resources/california_vacation.csv ", skiprows=1, header=None, names=['Month', ' California Vacation'])
# chicago_vacation_df  = pd.read_csv("resources/chicago_vacation.csv", skiprows=1, header=None, names=['Month', 'Chicago Vacation'])
# destination_wedding_locations_df = pd.read_csv("resources/destination_wedding_locations.csv ", skiprows=1, header=None, names=['Month', 'Destination Wedding Locations'])
# detroit_vacation_df  = pd.read_csv("resources/detroit_vacation.csv", skiprows=1, header=None, names=['Month', 'Detroit Vacation'])
# england_vacation_df  = pd.read_csv("resources/england_vacation.csv", skiprows=1, header=None, names=['Month', 'England Vacation'])
# european_vacation_df  = pd.read_csv("resources/european_vacation.csv", skiprows=1, header=None, names=['Month', 'European Vacation'])
# europe_vacation_df  = pd.read_csv("resources/europe_vacation.csv", skiprows=1, header=None, names=['Month', 'Europe Vacation'])
# florida_vacation_df  = pd.read_csv("resources/florida_vacation.csv", skiprows=1, header=None, names=['Month', 'Florida Vacation'])
# japan_vacation_df  = pd.read_csv("resources/japan_vacation.csv", skiprows=1, header=None, names=['Month', 'Japan Vacation'])
# las_vegas_vacation_df  = pd.read_csv("resources/las_vegas_vacation.csv", skiprows=1, header=None, names=['Month', 'Las Vegas Vacation'])
# london_vacation_df  = pd.read_csv("resources/london_vacation.csv", skiprows=1, header=None, names=['Month', 'London Vacation'])
# michigan_vacation_df  = pd.read_csv("resources/michigan_vacation.csv", skiprows=1, header=None, names=['Month', 'Michigan Vacation'])
# new_york_city_vacation_df = pd.read_csv("resources/new_york_city_vacation.csv", skiprows=1, header=None, names=['Month', 'New York City Vacation'])
# paris_vacation_df  = pd.read_csv("resources/paris_vacation.csv", skiprows=1, header=None, names=['Month', 'Paris Vacation'])
# rome_vacation_df  = pd.read_csv("resources/rome_vacation.csv", skiprows=1, header=None, names=['Month', 'Rome Vacation'])
# spain_vacation_df  = pd.read_csv("resources/spain_vacation.csv", skiprows=1, header=None, names=['Month', 'Spain Vacation'])
# russia_vacation_df  = pd.read_csv("resources/russia_vacation.csv", skiprows=1, header=None, names=['Month', 'Russia Vacation'])
# texas_vacation_df  = pd.read_csv("resources/texas_vacation.csv", skiprows=1, header=None, names=['Month', 'Texas Vacation'])

# # Find Things Now
# attractions_near_me_df = pd.read_csv("resources/attractions_near_me.csv", skiprows=1, header=None, names=['Month', 'Attractions Near Me'])
# food_near_me_df  = pd.read_csv("resources/food_near_me.csv", skiprows=1, header=None, names=['Month', 'Food Near Me'])
# restaurants_near_me_df  = pd.read_csv("resources/restaurants_near_me.csv", skiprows=1, header=None, names=['Month', 'Restaurants Near Me'])
# sightseeing_near_me_df  = pd.read_csv("resources/sightseeing_near_me.csv", skiprows=1, header=None, names=['Month', 'Sightseeing Near Me'])
# tourist_attractions_near_me_df  = pd.read_csv("resources/tourist_attractions_near_me.csv", skiprows=1, header=None, names=['Month', 'Tourist Attractions Near Me'])

# # # Reasons to Travel
# diving_trip_df  = pd.read_csv("resources/diving_trip.csv", skiprows=1, header=None, names=['Month', 'Diving Trip'])
# fishing_trip_df  = pd.read_csv("resources/fishing_trip.csv", skiprows=1, header=None, names=['Month', 'Fishing Trip'])
# golf_trip_df  = pd.read_csv("resources/golf_trip.csv", skiprows=1, header=None, names=['Month', 'Golf Trip'])
# golf_vacation_df  = pd.read_csv("resources/golf_vacation.csv", skiprows=1, header=None, names=['Month', 'Golf Vacation'])
# hunting_trip_df  = pd.read_csv("resources/hunting_trip.csv", skiprows=1, header=None, names=['Month', 'Hunting Trip'])
# las_vegas_casinos_df  = pd.read_csv("resources/las_vegas_casinos.csv", skiprows=1, header=None, names=['Month', 'Las Vegas Casinos'])
# mgm_df  = pd.read_csv("resources/mgm.csv", skiprows=1, header=None, names=['Month', 'MGM'])
# michelin_star_restaurants_df  = pd.read_csv("resources/michelin_star_restaurants.csv", skiprows=1, header=None, names=['Month', 'Michelin Star Restaurants'])
# scuba_diving_trip_df  = pd.read_csv("resources/scuba_diving_trip.csv", skiprows=1, header=None, names=['Month', 'Scuba Diving Trip'])
# sightseeing_df  = pd.read_csv("resources/sightseeing.csv", skiprows=1, header=None, names=['Month', 'Sightseeing'])
# tourist_traps_df  = pd.read_csv("resources/tourist_traps.csv", skiprows=1, header=None, names=['Month', 'Tourist Traps'])
# travel_leisure_df  = pd.read_csv("resources/travel_leisure.csv", skiprows=1, header=None, names=['Month', 'Travel + Leisure'])
# tropical_vacations_df  = pd.read_csv("resources/tropical_vacations.csv", skiprows=1, header=None, names=['Month', 'Tropical Vacations'])
# wine_country_vacation_df  = pd.read_csv("resources/wine_country_vacation.csv", skiprows=1, header=None, names=['Month', 'Wine Country Vacation'])

# Travel Booking
# expedia_df  = pd.read_csv("resources/expedia.csv", skiprows=1, header=None, names=['Month', 'Expedia'])
# tripadvisor_df  = pd.read_csv("resources/tripadvisor.csv", skiprows=1, header=None, names=['Month', 'Tripadvisor'])
# travelocity_df  = pd.read_csv("resources/travelocity.csv", skiprows=1, header=None, names=['Month', 'Travelocity'])
# orbitz_df  = pd.read_csv("resources/orbitz.csv", skiprows=1, header=None, names=['Month', 'Orbitz'])

# Trip Ideas
# getaway_df  = pd.read_csv("resources/getaway.csv", skiprows=1, header=None, names=['Month', 'Getaway'])
# long_weekend_trip_ideas_df  = pd.read_csv("resources/long_weekend_trip_ideas.csv", skiprows=1, header=None, names=['Month', 'Long Weekend Trip Ideas'])
# long_weekend_vacations_df  = pd.read_csv("resources/long_weekend_vacations.csv", skiprows=1, header=None, names=['Month', 'Long Weekend Vacations'])
# long_weekend_vacation_ideas_df  = pd.read_csv("resources/long_weekend_vacation_ideas.csv", skiprows=1, header=None, names=['Month', 'Long Weekend Vacation Ideas'])
# trips_df  = pd.read_csv("resources/trips.csv", skiprows=1, header=None, names=['Month', ' Trips'])
# vacation_df  = pd.read_csv("resources/vacation.csv", skiprows=1, header=None, names=['Month', 'Vacation'])
# cheapest_trips_df  = pd.read_csv("resources/cheapest_trips.csv", skiprows=1, header=None, names=['Month', 'Cheapest Trips'])
# most_expensive_trips_df  = pd.read_csv("resources/most_expensive_trips.csv", skiprows=1, header=None, names=['Month', 'Most Expensive Trips'])

# # # Companies
# global_business_travel_group_df  = pd.read_csv("resources/global_business_travel_group.csv", skiprows=1, header=None, names=['Month', 'Global Business Travel Group'])
# host_hotels_resorts_df  = pd.read_csv("resources/host_hotels_resorts.csv", skiprows=1, header=None, names=['Month', 'Host Hotels & Resorts'])
# las_vegas_sands_df  = pd.read_csv("resources/las_vegas_sands.csv", skiprows=1, header=None, names=['Month', 'Las Vegas Sands'])
# pebblebrook_df  = pd.read_csv("resources/pebblebrook.csv", skiprows=1, header=None, names=['Month', 'Pebblebrook'])
# playa_hotels_resorts_df  = pd.read_csv("resources/playa_hotels_resorts.csv", skiprows=1, header=None, names=['Month', 'Playa Hotels & Resorts'])
# ryman_hospitality_properties_df  = pd.read_csv("resources/ryman_hospitality_properties.csv", skiprows=1, header=None, names=['Month', 'Ryman Hospitality Properties'])
# sunstone_hotel_investors_df  = pd.read_csv("resources/sunstone_hotel_investors.csv", skiprows=1, header=None, names=['Month', 'Sunstone Hotel Investors'])
# vail_resorts_df  = pd.read_csv("resources/vail_resorts.csv", skiprows=1, header=None, names=['Month', 'Vail Resorts'])
# xenia_hotels_resorts_df  = pd.read_csv("resources/xenia_hotels_resorts.csv", skiprows=1, header=None, names=['Month', 'Xenia Hotels & Resorts'])

# All
# list_of_dfs = [enterprise_df, hertz_df, budget_df, alamo_df, travelocity_df, orbitz_df, airbnb_df, air_transport_services_group_df, alaska_airlines_df, allegiant_air_df, american_airlines_df, asia_vacation_df, attractions_near_me_df, best_cities_for_foodies_df, best_cities_to_visit_df, best_tourist_spots_df, big_city_vacations_df, bluegreen_vacations_df, booking_dot_com_df, california_vacation_df, carnival_cruises_df, carnival_cruise_lines_df, car_rental_df, cheapest_trips_df, chicago_vacation_df, choice_hotels_international_df, cruises_df, delta_airlines_df, delta_air_lines_df, destination_wedding_locations_df, detroit_vacation_df, diving_trip_df, england_vacation_df, european_vacation_df, europe_vacation_df, expedia_df, fishing_trip_df, flights_df, florida_vacation_df, food_near_me_df, frontier_airlines_df, getaway_df, global_business_travel_group_df, golf_trip_df, golf_vacation_df, hilton_df, host_hotels_resorts_df, hotels_df, hunting_trip_df, hyatt_df, japan_vacation_df, jetblue_df, las_vegas_casinos_df, las_vegas_sands_df, las_vegas_vacation_df, london_vacation_df, long_weekend_trip_ideas_df, long_weekend_vacations_df, long_weekend_vacation_ideas_df, marriott_df, mgm_df, michigan_vacation_df, michelin_star_restaurants_df, most_expensive_trips_df, motels_df, new_york_city_vacation_df, norwegian_cruises_df, paris_vacation_df, pebblebrook_df, playa_hotels_resorts_df, restaurants_near_me_df, rome_vacation_df,royal_caribbean_df, russia_vacation_df, ryman_hospitality_properties_df, scuba_diving_trip_df, sightseeing_df, sightseeing_near_me_df, skywest_airlines_df, southwest_airlines, spain_vacation_df, spirit_airlines_df, sunstone_hotel_investors_df, texas_vacation_df, tourist_attractions_near_me_df, tourist_traps_df, travel_leisure_df, tripadvisor_df, trips_df, tropical_vacations_df, united_airlines_df, vacation_df, vail_resorts_df, wine_country_vacation_df, wyndham_df, wynn_df, xenia_hotels_resorts_df, avis_df]

# Lodging
# list_of_dfs = [airbnb_df, bluegreen_vacations_df, booking_dot_com_df, choice_hotels_international_df, hilton_df, hotels_df, hyatt_df, marriott_df, motels_df, wyndham_df, wynn_df]

# Air
# list_of_dfs = [air_transport_services_group_df, alaska_airlines_df, allegiant_air_df, american_airlines_df, delta_airlines_df, delta_air_lines_df, flights_df, frontier_airlines_df, jetblue_df, skywest_airlines_df, southwest_airlines, spirit_airlines_df, united_airlines_df]

# Sea
list_of_dfs = [carnival_cruises_df, carnival_cruise_lines_df, cruises_df, norwegian_cruises_df, royal_caribbean_df, best_cruise_line_df, most_fun_cruise_df]

# # Land
# list_of_dfs = [car_rental_df, avis_df, enterprise_df, hertz_df, budget_df, alamo_df]

# # Locations
# list_of_dfs = [asia_vacation_df, best_cities_for_foodies_df, best_cities_to_visit_df, best_tourist_spots_df, big_city_vacations_df, california_vacation_df, chicago_vacation_df, destination_wedding_locations_df, detroit_vacation_df, england_vacation_df, european_vacation_df, europe_vacation_df, florida_vacation_df, japan_vacation_df, las_vegas_vacation_df, london_vacation_df, michigan_vacation_df, new_york_city_vacation_df, paris_vacation_df, rome_vacation_df, spain_vacation_df, russia_vacation_df, texas_vacation_df]

# # Find Things Now
# list_of_dfs = [attractions_near_me_df, food_near_me_df, restaurants_near_me_df, sightseeing_near_me_df, tourist_attractions_near_me_df]

# # Reasons to Travel
# list_of_dfs = [diving_trip_df, fishing_trip_df, golf_trip_df, golf_vacation_df, hunting_trip_df, las_vegas_casinos_df, mgm_df, michelin_star_restaurants_df, scuba_diving_trip_df, sightseeing_df, tourist_traps_df, travel_leisure_df, tropical_vacations_df, wine_country_vacation_df]

# Travel Booking
# list_of_dfs = [expedia_df, tripadvisor_df, travelocity_df, orbitz_df]

# Trip Ideas
# list_of_dfs = [getaway_df, long_weekend_trip_ideas_df, long_weekend_vacations_df, long_weekend_vacation_ideas_df, trips_df, vacation_df, cheapest_trips_df, most_expensive_trips_df]

# # Companies
# list_of_dfs = [global_business_travel_group_df, host_hotels_resorts_df, las_vegas_sands_df, pebblebrook_df, playa_hotels_resorts_df, ryman_hospitality_properties_df, sunstone_hotel_investors_df, vail_resorts_df, xenia_hotels_resorts_df]

# %%
# Run 3rd 
# Clean the dataframes

def clean_dataframes(dfs_list):
    for df in dfs_list:
        df.drop(0, inplace=True)

clean_dataframes(list_of_dfs)

# Display the dataframes

for df in list_of_dfs:
    print(df)
# Out:
#        Month Carnival Cruise Lines
# 1    2014-01                    37
# 2    2014-02                    29
# 3    2014-03                    30
# 4    2014-04                    24
# 5    2014-05                    26
# ..       ...                   ...
# 116  2023-08                    22
# 117  2023-09                    20
# 118  2023-10                    17
# 119  2023-11                    19
# 120  2023-12                    21
#
# [120 rows x 2 columns]
#        Month Carnival Cruises
# 1    2014-01               94
# 2    2014-02               76
# 3    2014-03               69
# 4    2014-04               61
# 5    2014-05               59
# ..       ...              ...
# 116  2023-08               33
# 117  2023-09               28
# 118  2023-10               26
# 119  2023-11               25
# 120  2023-12               29
#
# [120 rows x 2 columns]
#        Month Cruises
# 1    2014-01      86
# 2    2014-02      69
# 3    2014-03      70
# 4    2014-04      62
# 5    2014-05      65
# ..       ...     ...
# 116  2023-08      68
# 117  2023-09      63
# 118  2023-10      55
# 119  2023-11      62
# 120  2023-12      63
#
# [120 rows x 2 columns]
#        Month Norwegian Cruises
# 1    2014-01                26
# 2    2014-02                20
# 3    2014-03                20
# 4    2014-04                16
# 5    2014-05                14
# ..       ...               ...
# 116  2023-08                17
# 117  2023-09                16
# 118  2023-10                15
# 119  2023-11                20
# 120  2023-12                19
#
# [120 rows x 2 columns]
#        Month Royal Caribbean
# 1    2014-01              63
# 2    2014-02              47
# 3    2014-03              54
# 4    2014-04              40
# 5    2014-05              44
# ..       ...             ...
# 116  2023-08              65
# 117  2023-09              62
# 118  2023-10              56
# 119  2023-11              69
# 120  2023-12              66
#
# [120 rows x 2 columns]
#        Month Best Cruise Line
# 1    2014-01               58
# 2    2014-02               39
# 3    2014-03               35
# 4    2014-04               31
# 5    2014-05               39
# ..       ...              ...
# 116  2023-08               58
# 117  2023-09               54
# 118  2023-10               52
# 119  2023-11               55
# 120  2023-12               59
#
# [120 rows x 2 columns]
#        Month Most Fun Cruise
# 1    2014-01              19
# 2    2014-02              18
# 3    2014-03              21
# 4    2014-04              25
# 5    2014-05              27
# ..       ...             ...
# 116  2023-08              28
# 117  2023-09              15
# 118  2023-10              36
# 119  2023-11              30
# 120  2023-12              43
#
# [120 rows x 2 columns]

# %%
# RUN 4th

def merge_and_plot_dfs(df_list, merge_on='Month', plot=True):
    # Merge all dataframes on the specified column
    merged_df = df_list[0]
    for df in df_list[1:]:
        merged_df = pd.merge(merged_df, df, on=merge_on)

    # Convert relevant columns to numeric, handling non-numeric values
    for col in merged_df.columns:
        if col != merge_on:
            merged_df[col] = pd.to_numeric(merged_df[col], errors='coerce')

    # Calculate the average
    cols_to_average = [col for col in merged_df.columns if col != merge_on]
    merged_df['Average of Search Terms'] = merged_df[cols_to_average].mean(axis=1)

    return merged_df

merged_df = merge_and_plot_dfs(list_of_dfs)

merged_df
# Out:
#        Month  Carnival Cruise Lines  Carnival Cruises  Cruises  \
# 0    2014-01                     37                94       86
# 1    2014-02                     29                76       69
# 2    2014-03                     30                69       70
# 3    2014-04                     24                61       62
# 4    2014-05                     26                59       65
# ..       ...                    ...               ...      ...
# 115  2023-08                     22                33       68
# 116  2023-09                     20                28       63
# 117  2023-10                     17                26       55
# 118  2023-11                     19                25       62
# 119  2023-12                     21                29       63
#
#      Norwegian Cruises  Royal Caribbean  Best Cruise Line  Most Fun Cruise  \
# 0                   26               63                58             19.0
# 1                   20               47                39             18.0
# 2                   20               54                35             21.0
# 3                   16               40                31             25.0
# 4                   14               44                39             27.0
# ..                 ...              ...               ...              ...
# 115                 17               65                58             28.0
# 116                 16               62                54             15.0
# 117                 15               56                52             36.0
# 118                 20               69                55             30.0
# 119                 19               66                59             43.0
#
#      Average of Search Terms
# 0                  54.714286
# 1                  42.571429
# 2                  42.714286
# 3                  37.000000
# 4                  39.142857
# ..                       ...
# 115                41.571429
# 116                36.857143
# 117                36.714286
# 118                40.000000
# 119                42.857143
#
# [120 rows x 9 columns]

# %%
# Plot that

plt.figure(figsize=(10, 6))  # You can adjust the figure size as needed
plt.plot(merged_df['Month'], merged_df['Average of Search Terms'], label='Average of Search Terms')

# Setting labels and title
plt.xlabel('Month')
plt.ylabel('Average of Search Terms')
plt.title('Average of Search Terms Over Time')

# Optionally, you can format the x-axis to show dates more clearly

# Adding a legend if necessary
plt.legend()

# Show the plot
plt.show()

# %%
# Run 5th

stock_and_google_trends_df = merged_df
merged_df = merged_df[['Month', 'Average of Search Terms']]
merged_df
# Out:
#        Month  Average of Search Terms
# 0    2014-01                54.714286
# 1    2014-02                42.571429
# 2    2014-03                42.714286
# 3    2014-04                37.000000
# 4    2014-05                39.142857
# ..       ...                      ...
# 115  2023-08                41.571429
# 116  2023-09                36.857143
# 117  2023-10                36.714286
# 118  2023-11                40.000000
# 119  2023-12                42.857143
#
# [120 rows x 2 columns]

# %%
# 5.5

avg_searchterm_prophet_df = merged_df
avg_searchterm_prophet_df
# Out:
#        Month  Average of Search Terms
# 0    2014-01                54.714286
# 1    2014-02                42.571429
# 2    2014-03                42.714286
# 3    2014-04                37.000000
# 4    2014-05                39.142857
# ..       ...                      ...
# 115  2023-08                41.571429
# 116  2023-09                36.857143
# 117  2023-10                36.714286
# 118  2023-11                40.000000
# 119  2023-12                42.857143
#
# [120 rows x 2 columns]

# %%
# Run 6th

import yfinance as yf
import pandas as pd

def get_stock_data(ticker_symbols, start_date='2014-01-01', end_date='2023-12-31'):
    stock_dfs = []

    for ticker_symbol in ticker_symbols:
        # Fetch stock data
        ticker = yf.Ticker(ticker_symbol)
        hist = ticker.history(start=start_date, end=end_date, interval="1mo")

        # Convert to DataFrame and process
        df = pd.DataFrame(hist).reset_index().rename(columns={'Date': 'Month'})

        # Convert 'Month' to datetime format (if not already)
        df['Month'] = pd.to_datetime(df['Month'])

        # Convert 'Month' to period (year-month format) and then to string (object)
        df['Month'] = df['Month'].dt.to_period('M').astype(str)

        # Create a new DataFrame with 'Month' and 'Close'
        close = f'Close {ticker_symbol}'
        stock_df = df[['Month', 'Close']]
        stock_df = stock_df.rename(columns={'Close': close})
        stock_dfs.append(stock_df)

    return stock_dfs

# %%
# Usage

list_of_stock_dfs = get_stock_data(ticker_list)

list_of_stock_dfs
# Out:
# C:\Users\Sean\AppData\Local\Temp\ipykernel_6820\1210093761.py:21: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df['Month'] = df['Month'].dt.to_period('M').astype(str)
# C:\Users\Sean\AppData\Local\Temp\ipykernel_6820\1210093761.py:21: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df['Month'] = df['Month'].dt.to_period('M').astype(str)
# C:\Users\Sean\AppData\Local\Temp\ipykernel_6820\1210093761.py:21: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df['Month'] = df['Month'].dt.to_period('M').astype(str)
# C:\Users\Sean\AppData\Local\Temp\ipykernel_6820\1210093761.py:21: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df['Month'] = df['Month'].dt.to_period('M').astype(str)
# C:\Users\Sean\AppData\Local\Temp\ipykernel_6820\1210093761.py:21: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df['Month'] = df['Month'].dt.to_period('M').astype(str)
# [       Month  Close CCL
#  0    2014-01  32.603554
#  1    2014-02  32.994572
#  2    2014-03  31.696379
#  3    2014-04  32.910316
#  4    2014-05  33.513100
#  ..       ...        ...
#  115  2023-08  15.820000
#  116  2023-09  13.720000
#  117  2023-10  11.460000
#  118  2023-11  15.060000
#  119  2023-12  18.540001
#
#  [120 rows x 2 columns],
#         Month   Close RCL
#  0    2014-01   43.444447
#  1    2014-02   46.361168
#  2    2014-03   48.020996
#  3    2014-04   46.762379
#  4    2014-05   48.663506
#  ..       ...         ...
#  115  2023-08   98.940002
#  116  2023-09   92.139999
#  117  2023-10   84.730003
#  118  2023-11  107.459999
#  119  2023-12  129.490005
#
#  [120 rows x 2 columns],
#         Month  Close NCLH
#  0    2014-01   35.020000
#  1    2014-02   34.270000
#  2    2014-03   32.270000
#  3    2014-04   32.770000
#  4    2014-05   33.750000
#  ..       ...         ...
#  115  2023-08   16.570000
#  116  2023-09   16.480000
#  117  2023-10   13.600000
#  118  2023-11   15.270000
#  119  2023-12   20.040001
#
#  [120 rows x 2 columns],
#         Month  Close CUK
#  0    2014-01  33.938694
#  1    2014-02  34.146603
#  2    2014-03  32.094688
#  3    2014-04  33.391537
#  4    2014-05  34.044125
#  ..       ...        ...
#  115  2023-08  14.300000
#  116  2023-09  12.250000
#  117  2023-10  10.360000
#  118  2023-11  13.480000
#  119  2023-12  16.860001
#
#  [120 rows x 2 columns],
#         Month  Close LIND
#  0    2014-01        9.67
#  1    2014-02        9.79
#  2    2014-03        9.85
#  3    2014-04        9.88
#  4    2014-05        9.96
#  ..       ...         ...
#  115  2023-08        9.05
#  116  2023-09        7.20
#  117  2023-10        6.22
#  118  2023-11        7.85
#  119  2023-12       11.27
#
#  [120 rows x 2 columns]]

# %%
###############################
merged_stocks = merge_and_plot_dfs(list_of_stock_dfs)

merge_on = 'Month'
columns_to_convert = [col for col in merged_stocks.columns if col != merge_on]

# Apply percent change to each column and multiply by 100 for percentage
for col in columns_to_convert:
    merged_stocks[f'{col} % Change'] = merged_stocks[col].pct_change() * 100

# SEAN'S COMMENT ON HIS INTERPRUTATION OF THE CODE, PROBABLY TOTALLY SUCKS, PROBABLY NEEDS FIXING, LOL:
#    Columns to keep is defined as Month in additon to all stocks as a whole if the change is not equal to average of search
#    terms percent change
columns_to_keep = [merge_on] + [col for col in merged_stocks.columns if '% Change' in col 
                                and col != 'Average of Search Terms % Change']

# Filter the DataFrame to keep only the desired columns
merged_stocks = merged_stocks[columns_to_keep]

cols_to_average = [col for col in merged_stocks.columns if col != merge_on]

merged_stocks['Average of Stocks % chng'] = merged_stocks[cols_to_average].mean(axis=1)
 
merged_stocks = merged_stocks[['Month', 'Average of Stocks % chng']]
#merged_stocks.dropna()
merged_stocks
# Out:
#        Month  Average of Stocks % chng
# 0    2014-01                       NaN
# 1    2014-02                  1.524982
# 2    2014-03                 -2.317324
# 3    2014-04                  1.420722
# 4    2014-05                  2.330341
# ..       ...                       ...
# 115  2023-08                -18.045374
# 116  2023-09                -11.093599
# 117  2023-10                -14.205964
# 118  2023-11                 25.368206
# 119  2023-12                 28.697406
#
# [120 rows x 2 columns]

# %%
# Run 7th
stock_and_google_trends_df = pd.merge(merged_df, merged_stocks, on='Month')
stock_and_google_trends_df
# Out:
#        Month  Average of Search Terms  Average of Stocks % chng
# 0    2014-01                54.714286                       NaN
# 1    2014-02                42.571429                  1.524982
# 2    2014-03                42.714286                 -2.317324
# 3    2014-04                37.000000                  1.420722
# 4    2014-05                39.142857                  2.330341
# ..       ...                      ...                       ...
# 115  2023-08                41.571429                -18.045374
# 116  2023-09                36.857143                -11.093599
# 117  2023-10                36.714286                -14.205964
# 118  2023-11                40.000000                 25.368206
# 119  2023-12                42.857143                 28.697406
#
# [120 rows x 3 columns]

# %%
# Run 8th

# Calculate percentage change for 'Stock Price'
#stock_and_google_trends_df['Stock Price % Change'] = stock_and_google_trends_df['Close'].pct_change() * 100

# Calculate percentage change for 'Y4'
stock_and_google_trends_df['Average Search Term % Change'] = stock_and_google_trends_df['Average of Search Terms'].pct_change() * 100
stock_and_google_trends_df.dropna()
# Out:
#        Month  Average of Search Terms  Average of Stocks % chng  \
# 1    2014-02                42.571429                  1.524982
# 2    2014-03                42.714286                 -2.317324
# 3    2014-04                37.000000                  1.420722
# 4    2014-05                39.142857                  2.330341
# 5    2014-06                44.428571                 -3.584543
# ..       ...                      ...                       ...
# 115  2023-08                41.571429                -18.045374
# 116  2023-09                36.857143                -11.093599
# 117  2023-10                36.714286                -14.205964
# 118  2023-11                40.000000                 25.368206
# 119  2023-12                42.857143                 28.697406
#
#      Average Search Term % Change
# 1                      -22.193211
# 2                        0.335570
# 3                      -13.377926
# 4                        5.791506
# 5                       13.503650
# ..                            ...
# 115                    -19.613260
# 116                    -11.340206
# 117                     -0.387597
# 118                      8.949416
# 119                      7.142857
#
# [119 rows x 4 columns]

# %%
stock_and_google_trends_df2 = stock_and_google_trends_df[
    stock_and_google_trends_df['Average of Search Terms'] > 53]

new_df = stock_and_google_trends_df2.copy()

# If the 'Month' column contains strings in the 'YYYY-MM' format
new_df['Month'] = new_df['Month'].str[-2:]

frequency = new_df['Month'].value_counts()

frequency
# Out:
# Month
# 01    5
# 02    2
# 06    1
# 03    1
# Name: count, dtype: int64

# %%
# Run 9th

new_df[['Average Search Term % Change', "Average of Stocks % chng"]].corr()
# Out:
#                               Average Search Term % Change  \
# Average Search Term % Change                      1.000000
# Average of Stocks % chng                          0.400771
#
#                               Average of Stocks % chng
# Average Search Term % Change                  0.400771
# Average of Stocks % chng                      1.000000

# %%
stock_and_google_trends_df2 = stock_and_google_trends_df[
    stock_and_google_trends_df['Average of Search Terms'] > 53]

new_df = stock_and_google_trends_df2.copy()

# If the 'Month' column contains strings in the 'YYYY-MM' format
new_df['Month'] = new_df['Month'].str[-2:]

frequency = new_df['Month'].value_counts()
frequency_2 = new_df[
    (new_df['Month'] == '01') | (new_df['Month'] == '02')
]
frequency_2.drop(0, inplace=True)
frequency = frequency_2['Month'].value_counts()
frequency_2
# Out:
# C:\Users\Sean\AppData\Local\Temp\ipykernel_6820\2264096607.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frequency_2.drop(0, inplace=True)
#     Month  Average of Search Terms  Average of Stocks % chng  \
# 48     01                59.285714                  7.353064
# 60     01                78.142857                 13.947305
# 61     02                64.714286                  3.489809
# 72     01                57.571429                 -9.547696
# 108    01                67.857143                 35.951575
# 109    02                58.285714                 -4.891866
#
#      Average Search Term % Change
# 48                     100.483092
# 60                      78.175896
# 61                     -17.184644
# 72                      63.821138
# 108                     61.016949
# 109                    -14.105263

# %%
# Run 9th

frequency_2[['Average Search Term % Change', "Average of Stocks % chng"]].corr()
# Out:
#                               Average Search Term % Change  \
# Average Search Term % Change                      1.000000
# Average of Stocks % chng                          0.331218
#
#                               Average of Stocks % chng
# Average Search Term % Change                  0.331218
# Average of Stocks % chng                      1.000000

# %%
# Run 10th
stock_and_google_trends_df[['Average Search Term % Change', "Average of Stocks % chng"]].plot()
# Out:
# <Axes: >

# %%
# Prophet looping
from prophet import Prophet
import matplotlib.pyplot as plt

# Model for dfs that go > 100
def logistic_forecast(df):
    # Ensure correct column names
    df.columns = ['ds', 'y']
    df['cap'] = 100
    df['floor'] = 0

    model = Prophet(growth='logistic')
    model.fit(df)

    # Make future dataframe and predict
    future = model.make_future_dataframe(periods=60, freq='M')
    future['cap'] = 100
    future['floor'] = 0
    forecast = model.predict(future)

    # Create and save the plot
    fig = model.plot(forecast)
    plt.close(fig)  # Close the plot to prevent it from displaying immediately

    return {'dataframe': forecast, 'plot': fig}


# Main Function

def df_forecast(df_list):
    results = {}  # Dictionary to store forecasts and plots

    for i, df in enumerate(df_list, start=1):
        # Ensure correct column names
        df.columns = ['ds', 'y']

        # Fit the Prophet model
        m = Prophet()
        m.fit(df)

        # Make future dataframe and predict
        future = m.make_future_dataframe(periods=60, freq='M')
        forecast = m.predict(future)

        # Check if any yhat values are above 100
        if forecast['yhat'].max() > 100:
            # Call logistic forecast function
            result = logistic_forecast(df)
        else:
            # Create and save the plot for non-logistic forecast
            fig = m.plot(forecast)
            plt.close(fig)  # Close the plot to prevent it from displaying immediately
            result = {'dataframe': forecast, 'plot': fig}

        # Store forecast and plot in the dictionary
        results[f'forecast{i}'] = result

    return results

# %%
dfs = list_of_dfs 

all_results = df_forecast(dfs)
# Out:
# 21:15:28 - cmdstanpy - INFO - Chain [1] start processing
# 21:15:28 - cmdstanpy - INFO - Chain [1] done processing
# 21:15:28 - cmdstanpy - INFO - Chain [1] start processing
# 21:15:28 - cmdstanpy - INFO - Chain [1] done processing
# 21:15:29 - cmdstanpy - INFO - Chain [1] start processing
# 21:15:29 - cmdstanpy - INFO - Chain [1] done processing
# 21:15:29 - cmdstanpy - INFO - Chain [1] start processing
# 21:15:29 - cmdstanpy - INFO - Chain [1] done processing
# 21:15:30 - cmdstanpy - INFO - Chain [1] start processing
# 21:15:30 - cmdstanpy - INFO - Chain [1] done processing
# 21:15:30 - cmdstanpy - INFO - Chain [1] start processing
# 21:15:30 - cmdstanpy - INFO - Chain [1] done processing
# 21:15:30 - cmdstanpy - INFO - Chain [1] start processing
# 21:15:30 - cmdstanpy - INFO - Chain [1] done processing
# 21:15:31 - cmdstanpy - INFO - Chain [1] start processing
# 21:15:31 - cmdstanpy - INFO - Chain [1] done processing
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\_libs\lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "<1"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[636], line 3
#       1 dfs = list_of_dfs
# ----> 3 all_results = df_forecast(dfs)
#
# Cell In[635], line 39, in df_forecast(df_list)
#      37 # Fit the Prophet model
#      38 m = Prophet()
# ---> 39 m.fit(df)
#      41 # Make future dataframe and predict
#      42 future = m.make_future_dataframe(periods=60, freq='M')
#
# File ~\anaconda3\envs\dev\lib\site-packages\prophet\forecaster.py:1217, in Prophet.fit(self, df, **kwargs)
#    1213 if self.history is not None:
#    1214     raise Exception('Prophet object can only be fit once. '
#    1215                     'Instantiate a new object.')
# -> 1217 model_inputs = self.preprocess(df, **kwargs)
#    1218 initial_params = self.calculate_initial_params(model_inputs.K)
#    1220 dat = dataclasses.asdict(model_inputs)
#
# File ~\anaconda3\envs\dev\lib\site-packages\prophet\forecaster.py:1135, in Prophet.preprocess(self, df, **kwargs)
#    1132     raise ValueError('Dataframe has less than 2 non-NaN rows.')
#    1133 self.history_dates = pd.to_datetime(pd.Series(history['ds'].unique(), name='ds')).sort_values()
# -> 1135 self.history = self.setup_dataframe(history, initialize_scales=True)
#    1136 self.set_auto_seasonalities()
#    1137 seasonal_features, prior_scales, component_cols, modes = (
#    1138     self.make_all_seasonality_features(self.history))
#
# File ~\anaconda3\envs\dev\lib\site-packages\prophet\forecaster.py:282, in Prophet.setup_dataframe(self, df, initialize_scales)
#     265 """Prepare dataframe for fitting or predicting.
#     266
#     267 Adds a time index and scales y. Creates auxiliary columns 't', 't_ix',
#    (...)
#     279 pd.DataFrame prepared for fitting or predicting.
#     280 """
#     281 if 'y' in df:  # 'y' will be in training data
# --> 282     df['y'] = pd.to_numeric(df['y'])
#     283     if np.isinf(df['y'].values).any():
#     284         raise ValueError('Found infinity in column y.')
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\tools\numeric.py:217, in to_numeric(arg, errors, downcast, dtype_backend)
#     215 coerce_numeric = errors not in ("ignore", "raise")
#     216 try:
# --> 217     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa
#     218         values,
#     219         set(),
#     220         coerce_numeric=coerce_numeric,
#     221         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     222         or isinstance(values_dtype, StringDtype),
#     223     )
#     224 except (ValueError, TypeError):
#     225     if errors == "raise":
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\_libs\lib.pyx:2322, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "<1" at position 81

# %%
from IPython.display import display

for key, result in all_results.items():
    print(key) 
    # Display the forecast DataFrame
    display(result['dataframe'])
    # Display the plot
    fig = result['plot']
    display(fig)

# %%
# forecast average search terms
listy = [avg_searchterm_prophet_df]
searcheterms_forecast = df_forecast(listy)
for key, result in searcheterms_forecast.items():
    print(key)
    # Display the forecast DataFrame
    display(result['dataframe'])
    # Display the plot
    fig = result['plot']
    display(fig)

# %%
stock_and_google_trends_df2 = stock_and_google_trends_df[
    stock_and_google_trends_df['Average of Search Terms'] > 50]

new_df = stock_and_google_trends_df2.copy()

# If the 'Month' column contains strings in the 'YYYY-MM' format
new_df['Month'] = new_df['Month'].str[-2:]

frequency = new_df['Month'].value_counts()
frequency

# %%
new_df[['Average Search Term % Change', "Average of Stocks % chng"]].corr()

# %%
ccl_df = list_of_stock_dfs[0][['Month', 'Close CCL', 'Open']]

# %%
ccl_df

# %%
# trading algo 

algo_dfs = [ccl_df, merged_df]

results = merge_and_plot_dfs(algo_dfs)
results
